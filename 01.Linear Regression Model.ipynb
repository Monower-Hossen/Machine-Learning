# %% [markdown]
# # Machine Learning 01: Linear Regression Model

# %% [markdown]
# ## 🔍 What is Linear Regression?
# Linear Regression is one of the simplest and most widely used supervised learning algorithms in machine learning.
# It is used to predict a **continuous target variable** based on one or more input features
# ## 📈 Objective
# To model the relationship between:
#
# - Dependent variable (y): What we want to predict.
# - Independent variable(s) (x): Features or inputs.

# %% [markdown]
# ## 🧠 Types of Linear Regression
#
# ## 1. Simple Linear Regression
#
# Predicts the target using **one feature**.
#
# ### Equation:
# $$
# y = mx + c
# $$
#
# ## 2. Multiple Linear Regression
#
# Predicts the target using **multiple features**.
#
# ### Equation:
# $$
# y = \beta_0 + \beta_1 x_1 + \beta_2 x_2 + \dots + \beta_n x_n
# $$

# %% [markdown]
# ## 🔢 Key Terms
#
# - **y** = dependend variable
# - **x** = independent variables
# - **m** = Slope/gradien/coefficient
# - **c** = Intercept

# %% [markdown]
# ## ✅ Assumptions of Linear Regression
#
# 1. **Linearity**: Linear relationship between independent and dependent variables.
# 2. **Independence**: Observations are independent of each other.
# 3. **Homoscedasticity**: Constant variance of errors.
# 4. **No multicollinearity**: Features should not be highly correlated.
# 5. **Normal distribution of errors**: Residuals should follow a normal distribution.

# %% [markdown]
# ## 📦 1. Importing Required Libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %% [markdown]
# - pandas: For loading and handling the dataset.
# - seaborn and matplotlib.pyplot: For plotting and visualization.
# - train_test_split: To split the dataset into training and testing parts.

# %% [markdown]
# ## 📄 2. Loading the Dataset

# %%
df =pd.read_csv("Placement.csv")
df.head(3)
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25

# %% [markdown]
# - Loads the Placement.csv dataset into a DataFrame.
# - Displays the first 3 rows to preview the data.

# %% [markdown]
# ## 📊 3. Scatter Plot of Data

# %%
plt.figure(figsize = (5,3))
sns.scatterplot(x="cgpa",y="package",data=df)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# - Plots a scatter plot of cgpa (x-axis) vs. package (y-axis) to visualize the relationship.
# - plt.show() displays the plot.

# %% [markdown]
# ## 🧹 4. Checking for Missing Values

# %%
df.isnull().sum()
# Out:
# cgpa       0
# package    0
# dtype: int64

# %% [markdown]
# - Checks how many missing values are in each column.
# - Output shows that both cgpa and package have 0 nulls, so the data is clean.

# %% [markdown]
# ## 🎯 5. Splitting Data into Features and Target

# %%
x = df[["cgpa"]]
y = df[["package"]]

# %% [markdown]
# - x is the independent variable.
# - y is the dependent variable (what we want to predict).

# %% [markdown]
# ## ✂️ 6. Train-Test Split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# - Splits the data: 80% for training, 20% for testing.
# - random_state ensures reproducibility.

# %% [markdown]
# ## 🧠 7. Training the Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# - Initializes and trains the Linear Regression model on training data.

# %% [markdown]
# ## 🧾 8. Getting Model Parameters

# %%
# y = m*x + c

# %%
lr.coef_        # Slope (m)
# Out:
# array([[0.57425647]])

# %%
lr.intercept_   # Intercept (c)
# Out:
# array([-1.02700694])

# %% [markdown]
# m = 0.57425647
#
# c = -1.02700694
#
# So the model equation is:
#                     𝑦=0.57425647⋅cgpa−1.02700694

# %% [markdown]
# ## 🎯 9. Evaluating the Model

# %%
lr.score(x_test,y_test)*100
# Out:
# 77.30984312051673

# %% [markdown]
# - Returns R² Score, i.e., how much variance is explained by the model.
# - Output: 77.30% → the model explains 77.3% of the variation in the data.

# %% [markdown]
# ## 🔮 10. Making a Prediction

# %%
lr.predict ([[6.89]])
# Out:
# C:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[2.92962016]])

# %% [markdown]
# - Predicts the package for CGPA = 6.89.
# - Output: 2.9296
#
# ### This matches the manual calculation:
#
# 𝑦=0.57425647⋅6.89−1.02700694
# = 2.9296

# %%
 0.57425647*6.89 -1.02700694
# Out:
# 2.9296201383

# %% [markdown]
# - Predicts the package for CGPA = 6.89.
# - Output: 2.9296
#
# This matches the manual calculation:
# 𝑦 = 0.57425647⋅6.89−1.02700694=2.9296

# %% [markdown]
# ## 📈 11. Plotting the Regression Line

# %%
y_prd = lr.predict(x)

# %%
plt.figure(figsize = (5,4))
sns.scatterplot(x="cgpa",y="package",data=df)
plt.plot(df["cgpa"],y_prd,c="red")
plt.legend(["ORG DATA","Predict Line"])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# - Plots the original data (scatter) and the predicted regression line in red.

# %% [markdown]
# ## 📌 Use Cases
# - Predicting house prices
# - Forecasting sales
# - Estimating salary based on experience
# - Stock price prediction (with caution)
